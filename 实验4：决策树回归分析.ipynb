# %%
# -*- coding: UTF-8 -*-
import sys
from time import time
import pandas as pd
import matplotlib.pyplot as plt
from pyspark import SparkConf, SparkContext
from pyspark.mllib.tree import DecisionTree
from pyspark.mllib.regression import LabeledPoint
import numpy as np
from pyspark.mllib.evaluation import RegressionMetrics
import math

# %%
def SetPath(sc):
    global Path
    if sc.master[0:5]=="local" :
        Path="file:/home/hduser/workspace/Classification/"
    else:   
        Path="hdfs://master:9000/user/hduser/"

# %%
def CreateSparkContext():
    sparkConf = SparkConf()                                            \
                         .setAppName("RunDecisionTreeRegression")           \
                         .set("spark.ui.showConsoleProgress", "false") 
    sc = SparkContext(conf = sparkConf)
    print ("master="+sc.master)    
    SetPath(sc)
    return (sc)

# %%
def extract_label(record):
    label=(record[-1])
    return float(label)

# %%
def convert_float(x):
    return (0 if x=="?" else float(x))

# %%
def extract_features(record,featureEnd):
    featureSeason=[convert_float(field)  for  field in record[2]] 
    features=[convert_float(field)  for  field in record[4: featureEnd-2]]
    return  np.concatenate( (featureSeason, features))

# %%
def PrepareData(sc): 
    #----------------------1.导入并转换数据-------------
    print("开始导入数据...")
    rawDataWithHeader = sc.textFile(Path+"data/hour.csv")
    header = rawDataWithHeader.first() 
    rawData = rawDataWithHeader.filter(lambda x:x !=header)    
    lines = rawData.map(lambda x: x.split(","))
    print (lines.first())
    print("共计：" + str(lines.count()) + "项")
    #----------------------2.建立训练评估所需数据 RDD[LabeledPoint]-------------
    labelpointRDD = lines.map(lambda r:LabeledPoint(
                                                    extract_label(r), 
                                                    extract_features(r,len(r) - 1)))
 
    print labelpointRDD.first()
    #----------------------3.以随机方式将数据分为3个部分并且返回-------------
    (trainData, validationData, testData) = labelpointRDD.randomSplit([8, 1, 1])
    print("将数据分trainData:" + str(trainData.count()) + 
             "   validationData:" + str(validationData.count()) +
             "   testData:" + str(testData.count()))
    #print labelpointRDD.first()
    return (trainData, validationData, testData) #返回数据

# %%
def trainEvaluateModel(trainData,validationData,
                                           impurityParm, maxDepthParm, maxBinsParm):
    startTime = time()
    model = DecisionTree.trainRegressor(trainData, 
                                  categoricalFeaturesInfo={}, \
                                  impurity=impurityParm, 
                                  maxDepth=maxDepthParm, 
                                  maxBins=maxBinsParm)
    RMSE = evaluateModel(model, validationData)
    duration = time() - startTime
    print    "训练评估：使用参数" + \
                " impurityParm= %s"%impurityParm+ \
                "  maxDepthParm= %s"%maxDepthParm+ \
                "  maxBinsParm = %d."%maxBinsParm + \
                 "  所需时间=%d"%duration + \
                 "  结果RMSE = %f " % RMSE 
    return (RMSE,duration, impurityParm, maxDepthParm, maxBinsParm,model)

# %%
def evaluateModel(model, validationData):
    score = model.predict(validationData.map(lambda p: p.features))
    scoreAndLabels=score.zip(validationData.map(lambda p: p.label))
    metrics = RegressionMetrics(scoreAndLabels)
    RMSE=metrics.rootMeanSquaredError
    return( RMSE)

# %%
def  parametersEval(training_RDD, validation_RDD):
    
    print("----- 评估maxDepth参数使用 ---------")
    evalParameter(training_RDD, validation_RDD,"maxDepth", 
                              impurityList=["variance"],       
                              maxDepthList =[3, 5, 10, 15, 20, 25]  ,
                              maxBinsList=[10])
    print("----- 评估maxBins参数使用 ---------")
    evalParameter(training_RDD, validation_RDD,"maxBins", 
                              impurityList=["variance"],        
                              maxDepthList=[10],                   
                              maxBinsList=[3, 5, 10, 50, 100, 200 ])

# %%
def evalParameter(trainData, validationData, evaparm,impurityList, maxDepthList, maxBinsList):
    metrics = [trainEvaluateModel(trainData, validationData,  impurity,maxdepth,  maxBins  ) 
                            for impurity in impurityList 
                            for maxdepth in maxDepthList  
                            for maxBins in maxBinsList ]
    if evaparm=="impurity":
        IndexList=impurityList[:]
    elif evaparm=="maxDepth":
        IndexList=maxDepthList[:]
    elif evaparm=="maxBins":
        IndexList=maxBinsList[:]
 
    df = pd.DataFrame(metrics,index=IndexList,
                      columns=['RMSE', 'duration','impurityParm', 'maxDepthParm', 'maxBinsParm','model'])
    
#     showchart(df,evaparm,'RMSE','duration',0,200 )
    ax = df['RMSE'].plot(kind='bar', title =evalparm,figsize=(10,6),legend=True, fontsize=12)
    ax.set_xlabel(evalparm,fontsize=12)
    ax.set_ylim([0,200])
    ax.set_ylabel("RMSE",fontsize=12)
    ax2 = ax.twinx()
    ax2.plot(df[['duration' ]].values, linestyle='-', marker='o', linewidth=2.0,color='r')
    plt.show()

# %%
# def showchart(df,evalparm ,barData,lineData,yMin,yMax):
#     ax = df[barData].plot(kind='bar', title =evalparm,figsize=(10,6),legend=True, fontsize=12)
#     ax.set_xlabel(evalparm,fontsize=12)
#     ax.set_ylim([yMin,yMax])
#     ax.set_ylabel(barData,fontsize=12)
#     ax2 = ax.twinx()
#     ax2.plot(df[[lineData ]].values, linestyle='-', marker='o', linewidth=2.0,color='r')
#     plt.show()

# %%
def evalAllParameter(training_RDD, validation_RDD, impurityList, maxDepthList, maxBinsList):    
    metrics = [trainEvaluateModel(trainData, validationData,  impurity,maxdepth,  maxBins  ) 
                        for impurity in impurityList 
                        for maxdepth in maxDepthList  
                        for maxBins in maxBinsList ]
    Smetrics = sorted(metrics, key=lambda k: k[0])
    bestParameter=Smetrics[0]
    
    print("调校后最佳参数：impurity:" + str(bestParameter[2]) + 
            "  ,maxDepth:" + str(bestParameter[3]) + 
            "  ,maxBins:" + str(bestParameter[4])   + 
            "  ,结果RMSE = " + str(bestParameter[0]))
    
    return bestParameter[5]

# %%
def PredictData(sc,model): 
    #----------------------1.导入并转换数据-------------
    print("开始导入数据...")
    rawDataWithHeader = sc.textFile(Path+"data/hour.csv")
    header = rawDataWithHeader.first() 
    rawData = rawDataWithHeader.filter(lambda x:x !=header)    
    lines = rawData.map(lambda x: x.split(","))
    #print (lines.first())
    print("共计：" + str(lines.count()) + "项")
    #----------------------2.建立训练评估所需数据 LabeledPoint RDD-------------
    labelpointRDD = lines.map(lambda r: LabeledPoint(
                                                     extract_label(r), 
                                                     extract_features(r,len(r) - 1)))
    #----------------------3.定义字典----------------
    SeasonDict = { 1 : "春",  2 : "夏",  3 :"秋",  4 : "冬"   }
    HoildayDict={  0 : "非假日", 1 : "假日"  }  
    WeekDict = {0:"一",1:"二",2:"三",3:"四",4 :"五",5:"六",6:"日"}
    WorkDayDict={ 1 : "工作日",  0 : "非工作日"  }
    WeatherDict={ 1 : "晴",  2 : "阴",  3 : "小雨", 4 : "大雨" }
    #----------------------4.进行预测并显示结果--------------
    for lp in labelpointRDD.take(20):
        predict = int(model.predict(lp.features))
        label=lp.label
        features=lp.features
        result = ("正确" if  (label == predict) else "错误")
        error = math.fabs(label - predict)
        dataDesc="  特征: "+SeasonDict[features[0]] +"季,"+\
                            str(features[1]) + "月," +\
                            str(features[2]) +  "时,"+ \
                            HoildayDict[features[3]] +","+\
                            "星期"+WeekDict[features[4]]+","+ \
                            WorkDayDict[features[5]]+","+\
                            WeatherDict[features[6]]+","+\
                            str(features[7] * 41)+ "度,"+\
                            "体感" + str(features[8] * 50) + "度," +\
                            "湿度" + str(features[9] * 100) + ","+\
                            "风速" + str(features[10] * 67) +\
                            " ==> 预测结果:" + str(predict )+\
                            "  , 实际:" + str(label) + result +",  误差:" + str(error)
        print dataDesc

# %%
if __name__ == "__main__":
    print("RunDecisionTreeRegression")
    sc.stop()
    sc=CreateSparkContext()
    print("==========数据准备阶段===============")
    (trainData, validationData, testData) =PrepareData(sc)
    trainData.persist(); validationData.persist(); testData.persist()
    print("==========训练评估阶段===============")
    (AUC,duration, impurityParm, maxDepthParm, maxBinsParm,model)= \
             trainEvaluateModel(trainData, validationData, "variance", 10, 100)

    flag_mark = 2
    
    if flag_mark == 1:
        parametersEval(trainData, validationData)
    elif flag_mark !=1:
        print("-----所有参数训练评估找出最好的参数组合---------")  
        model=evalAllParameter(trainData, validationData,
                          ["variance"],
                          [3, 5, 10, 15, 20, 25], 
                          [3, 5, 10, 50, 100, 200 ])
    print("==========测试阶段===============")
    RMSE = evaluateModel(model, testData)
    print("使用test Data测试最佳模型,结果 RMSE:" + str(RMSE))
    print("==========预测数据===============")
    PredictData(sc, model)
    #print   model.toDebugString()
# Out:
# RunDecisionTreeRegression
# master=local[*]
# ==========数据准备阶段===============
# 开始导入数据...
# [u'1', u'2011-01-01', u'1', u'0', u'1', u'0', u'0', u'6', u'0', u'1', u'0.24', u'0.2879', u'0.81', u'0', u'3', u'13', u'16']
# 共计：17379项
# (16.0,[1.0,1.0,0.0,0.0,6.0,0.0,1.0,0.24,0.2879,0.81,0.0])
# 将数据分trainData:13903   validationData:1717   testData:1759
# ==========训练评估阶段===============
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 10  maxBinsParm = 100.  所需时间=9  结果RMSE = 79.310488
# -----所有参数训练评估找出最好的参数组合---------
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 3  maxBinsParm = 3.  所需时间=1  结果RMSE = 142.436809
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 3  maxBinsParm = 5.  所需时间=0  结果RMSE = 144.612046
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 3  maxBinsParm = 10.  所需时间=0  结果RMSE = 134.485345
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 3  maxBinsParm = 50.  所需时间=0  结果RMSE = 132.982427
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 3  maxBinsParm = 100.  所需时间=0  结果RMSE = 132.982427
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 3  maxBinsParm = 200.  所需时间=0  结果RMSE = 132.982427
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 5  maxBinsParm = 3.  所需时间=0  结果RMSE = 133.124432
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 5  maxBinsParm = 5.  所需时间=0  结果RMSE = 132.471204
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 5  maxBinsParm = 10.  所需时间=0  结果RMSE = 113.994222
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 5  maxBinsParm = 50.  所需时间=0  结果RMSE = 115.412804
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 5  maxBinsParm = 100.  所需时间=0  结果RMSE = 115.412804
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 5  maxBinsParm = 200.  所需时间=0  结果RMSE = 115.412804
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 10  maxBinsParm = 3.  所需时间=0  结果RMSE = 126.054777
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 10  maxBinsParm = 5.  所需时间=0  结果RMSE = 121.083821
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 10  maxBinsParm = 10.  所需时间=0  结果RMSE = 87.657499
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 10  maxBinsParm = 50.  所需时间=0  结果RMSE = 79.057935
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 10  maxBinsParm = 100.  所需时间=1  结果RMSE = 79.310488
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 10  maxBinsParm = 200.  所需时间=1  结果RMSE = 79.310488
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 15  maxBinsParm = 3.  所需时间=1  结果RMSE = 130.114344
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 15  maxBinsParm = 5.  所需时间=1  结果RMSE = 129.746358
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 15  maxBinsParm = 10.  所需时间=1  结果RMSE = 94.496872
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 15  maxBinsParm = 50.  所需时间=1  结果RMSE = 84.820290
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 15  maxBinsParm = 100.  所需时间=2  结果RMSE = 85.731384
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 15  maxBinsParm = 200.  所需时间=1  结果RMSE = 85.731384
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 20  maxBinsParm = 3.  所需时间=1  结果RMSE = 130.011949
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 20  maxBinsParm = 5.  所需时间=2  结果RMSE = 135.655673
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 20  maxBinsParm = 10.  所需时间=2  结果RMSE = 102.489566
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 20  maxBinsParm = 50.  所需时间=2  结果RMSE = 90.712799
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 20  maxBinsParm = 100.  所需时间=2  结果RMSE = 91.791072
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 20  maxBinsParm = 200.  所需时间=2  结果RMSE = 91.791072
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 25  maxBinsParm = 3.  所需时间=1  结果RMSE = 130.011949
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 25  maxBinsParm = 5.  所需时间=2  结果RMSE = 135.548987
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 25  maxBinsParm = 10.  所需时间=2  结果RMSE = 102.873152
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 25  maxBinsParm = 50.  所需时间=3  结果RMSE = 92.148977
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 25  maxBinsParm = 100.  所需时间=3  结果RMSE = 92.883418
# 训练评估：使用参数 impurityParm= variance  maxDepthParm= 25  maxBinsParm = 200.  所需时间=3  结果RMSE = 92.883418
# 调校后最佳参数：impurity:variance  ,maxDepth:10  ,maxBins:50  ,结果RMSE = 79.0579350237
# ==========测试阶段===============
# 使用test Data测试最佳模型,结果 RMSE:80.6230036293
# ==========预测数据===============
# 开始导入数据...
# 共计：17379项
#   特征: 春季,1.0月,0.0时,非假日,星期日,非工作日,晴,9.84度,体感14.395度,湿度81.0,风速0.0 ==> 预测结果:31  , 实际:16.0错误,  误差:15.0
#   特征: 春季,1.0月,1.0时,非假日,星期日,非工作日,晴,9.02度,体感13.635度,湿度80.0,风速0.0 ==> 预测结果:31  , 实际:40.0错误,  误差:9.0
#   特征: 春季,1.0月,2.0时,非假日,星期日,非工作日,晴,9.02度,体感13.635度,湿度80.0,风速0.0 ==> 预测结果:34  , 实际:32.0错误,  误差:2.0
#   特征: 春季,1.0月,3.0时,非假日,星期日,非工作日,晴,9.84度,体感14.395度,湿度75.0,风速0.0 ==> 预测结果:16  , 实际:13.0错误,  误差:3.0
#   特征: 春季,1.0月,4.0时,非假日,星期日,非工作日,晴,9.84度,体感14.395度,湿度75.0,风速0.0 ==> 预测结果:5  , 实际:1.0错误,  误差:4.0
#   特征: 春季,1.0月,5.0时,非假日,星期日,非工作日,阴,9.84度,体感12.879999999999999度,湿度75.0,风速6.0032 ==> 预测结果:5  , 实际:1.0错误,  误差:4.0
#   特征: 春季,1.0月,6.0时,非假日,星期日,非工作日,晴,9.02度,体感13.635度,湿度80.0,风速0.0 ==> 预测结果:10  , 实际:2.0错误,  误差:8.0
#   特征: 春季,1.0月,7.0时,非假日,星期日,非工作日,晴,8.200000000000001度,体感12.879999999999999度,湿度86.0,风速0.0 ==> 预测结果:13  , 实际:3.0错误,  误差:10.0
#   特征: 春季,1.0月,8.0时,非假日,星期日,非工作日,晴,9.84度,体感14.395度,湿度75.0,风速0.0 ==> 预测结果:55  , 实际:8.0错误,  误差:47.0
#   特征: 春季,1.0月,9.0时,非假日,星期日,非工作日,晴,13.120000000000001度,体感17.424999999999997度,湿度76.0,风速0.0 ==> 预测结果:159  , 实际:14.0错误,  误差:145.0
#   特征: 春季,1.0月,10.0时,非假日,星期日,非工作日,晴,15.58度,体感19.695度,湿度76.0,风速16.997899999999998 ==> 预测结果:159  , 实际:36.0错误,  误差:123.0
#   特征: 春季,1.0月,11.0时,非假日,星期日,非工作日,晴,14.76度,体感16.665度,湿度81.0,风速19.0012 ==> 预测结果:255  , 实际:56.0错误,  误差:199.0
#   特征: 春季,1.0月,12.0时,非假日,星期日,非工作日,晴,17.22度,体感21.21度,湿度77.0,风速19.0012 ==> 预测结果:255  , 实际:84.0错误,  误差:171.0
#   特征: 春季,1.0月,13.0时,非假日,星期日,非工作日,阴,18.86度,体感22.725度,湿度72.0,风速19.999499999999998 ==> 预测结果:126  , 实际:94.0错误,  误差:32.0
#   特征: 春季,1.0月,14.0时,非假日,星期日,非工作日,阴,18.86度,体感22.725度,湿度72.0,风速19.0012 ==> 预测结果:126  , 实际:106.0错误,  误差:20.0
#   特征: 春季,1.0月,15.0时,非假日,星期日,非工作日,阴,18.04度,体感21.97度,湿度77.0,风速19.999499999999998 ==> 预测结果:126  , 实际:110.0错误,  误差:16.0
#   特征: 春季,1.0月,16.0时,非假日,星期日,非工作日,阴,17.22度,体感21.21度,湿度82.0,风速19.999499999999998 ==> 预测结果:126  , 实际:93.0错误,  误差:33.0
#   特征: 春季,1.0月,17.0时,非假日,星期日,非工作日,阴,18.04度,体感21.97度,湿度82.0,风速19.0012 ==> 预测结果:126  , 实际:67.0错误,  误差:59.0
#   特征: 春季,1.0月,18.0时,非假日,星期日,非工作日,小雨,17.22度,体感21.21度,湿度88.0,风速16.997899999999998 ==> 预测结果:97  , 实际:35.0错误,  误差:62.0
#   特征: 春季,1.0月,19.0时,非假日,星期日,非工作日,小雨,17.22度,体感21.21度,湿度88.0,风速16.997899999999998 ==> 预测结果:97  , 实际:37.0错误,  误差:60.0
